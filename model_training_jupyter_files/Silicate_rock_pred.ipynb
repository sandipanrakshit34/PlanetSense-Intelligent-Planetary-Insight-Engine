# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import os

tf.random.set_seed(42)
np.random.seed(42)

igneous_rock_properties = {
"Olivine":     {"velocity": (5.2, 0.1), "amplitude": (0.65, 0.02), "duration": (285, 10), "frequency_Hz": (45, 5)},
    "Pyroxene":    {"velocity": (5.0, 0.1), "amplitude": (0.62, 0.02), "duration": (295, 10), "frequency_Hz": (43, 5)},
    "Amphibole":   {"velocity": (5.1, 0.1), "amplitude": (0.60, 0.02), "duration": (280, 10), "frequency_Hz": (42, 5)},
    "Mica":        {"velocity": (5.0, 0.1), "amplitude": (0.61, 0.02), "duration": (290, 10), "frequency_Hz": (44, 5)},
    "Feldspar":    {"velocity": (5.1, 0.1), "amplitude": (0.64, 0.02), "duration": (300, 10), "frequency_Hz": (46, 5)},

}

def generate_dataset(props, samples_per_class=800, seed=42):
    """Generate dataset with more samples for better training"""
    np.random.seed(seed)
    data = []

    for rock_type, features in props.items():
        for _ in range(samples_per_class):
            row = {
                "rock_type": rock_type,
                "velocity": np.random.normal(*features["velocity"]),
                "amplitude": np.random.normal(*features["amplitude"]),
                "duration": np.random.normal(*features["duration"]),
                "frequency_Hz": np.random.normal(*features["frequency_Hz"])
            }
            data.append(row)

    df = pd.DataFrame(data)
    df = df.sample(frac=1, random_state=seed).reset_index(drop=True)
    return df

df = generate_dataset(igneous_rock_properties)

df['velocity_x_amplitude'] = df['velocity'] * df['amplitude']
df['velocity_squared'] = df['velocity'] ** 2
df['duration_squared'] = df['duration'] ** 2
df['amplitude_duration'] = df['amplitude'] * df['duration']
df['velocity_frequency'] = df['velocity'] * df['frequency_Hz']
df['amplitude_frequency'] = df['amplitude'] * df['frequency_Hz']
df['duration_frequency'] = df['duration'] * df['frequency_Hz']
df['velocity_duration'] = df['velocity'] * df['duration']
df['amplitude_squared'] = df['amplitude'] ** 2
df['frequency_squared'] = df['frequency_Hz'] ** 2
df['velocity_amplitude_ratio'] = df['velocity'] / df['amplitude']
df['duration_frequency_ratio'] = df['duration'] / df['frequency_Hz']
df['velocity_duration_ratio'] = df['velocity'] / df['duration']
df['velocity_cubed'] = df['velocity'] ** 3
df['amplitude_cubed'] = df['amplitude'] ** 3

print(df)
# Out:
#      rock_type  velocity  amplitude    duration  frequency_Hz  \
# 0      Olivine  5.164166   0.637049  292.441920     44.093879
# 1     Feldspar  5.117872   0.636524  309.959549     49.681137
# 2      Olivine  5.167138   0.662064  279.558860     44.186035
# 3     Feldspar  5.131816   0.648273  290.513781     46.365521
# 4         Mica  5.138487   0.617933  281.668585     49.329819
# ...        ...       ...        ...         ...           ...
# 3995  Pyroxene  4.951229   0.641487  299.964001     53.375325
# 3996  Pyroxene  4.869841   0.582940  293.751131     43.078489
# 3997  Pyroxene  5.014552   0.607718  296.409827     50.943135
# 3998  Feldspar  5.173976   0.669704  311.176324     48.509260
# 3999      Mica  5.142326   0.607332  276.135106     41.380784
#
#       velocity_x_amplitude  velocity_squared  duration_squared  \
# 0                 3.289828         26.668610      85522.276407
# 1                 3.257647         26.192609      96074.922191
# 2                 3.420975         26.699317      78153.156193
# 3                 3.326817         26.335535      84398.256944
# 4                 3.175238         26.404050      79337.191644
# ...                    ...               ...               ...
# 3995              3.176148         24.514673      89978.402002
# 3996              2.838823         23.715353      86289.727050
# 3997              3.047431         25.145733      87858.785540
# 3998              3.465034         26.770027      96830.704877
# 3999              3.123100         26.443522      76250.596651
#
#       amplitude_duration  velocity_frequency  amplitude_frequency  \
# 0             186.299880          227.708111            28.089969
# 1             197.296600          254.261677            31.623221
# 2             185.085787          228.315350            29.253972
# 3             188.332228          237.939321            30.057514
# 4             174.052189          253.480637            30.482501
# ...                  ...                 ...                  ...
# 3995          192.422905          264.273483            34.239559
# 3996          171.239176          209.785401            25.112158
# 3997          180.133453          255.457004            30.959037
# 3998          208.396132          250.985745            32.486862
# 3999          167.705740          212.793503            25.131882
#
#       duration_frequency  velocity_duration  amplitude_squared  \
# 0           12894.898662        1510.218614           0.405832
# 1           15399.142902        1586.333147           0.405162
# 2           12352.597703        1444.519251           0.438328
# 3           13469.822892        1490.863250           0.420258
# 4           13894.660191        1447.350392           0.381841
# ...                  ...                ...                ...
# 3995        16010.676110        1485.190600           0.411505
# 3996        12654.354866        1430.521362           0.339819
# 3997        15100.045725        1486.362526           0.369321
# 3998        15094.933304        1610.018812           0.448504
# 3999        11426.687209        1419.976870           0.368852
#
#       frequency_squared  velocity_amplitude_ratio  duration_frequency_ratio  \
# 0           1944.270177                  8.106385                  6.632257
# 1           2468.215396                  8.040347                  6.238979
# 2           1952.405731                  7.804593                  6.326860
# 3           2149.761563                  7.916135                  6.265729
# 4           2433.431003                  8.315612                  5.709905
# ...                 ...                       ...                       ...
# 3995        2848.925340                  7.718367                  5.619900
# 3996        1855.756213                  8.353937                  6.818975
# 3997        2595.202967                  8.251452                  5.818445
# 3998        2353.148330                  7.725761                  6.414782
# 3999        1712.369297                  8.467074                  6.673027
#
#       velocity_duration_ratio  velocity_cubed  amplitude_cubed
# 0                    0.017659      137.721130         0.258535
# 1                    0.016511      134.050407         0.257895
# 2                    0.018483      137.959058         0.290201
# 3                    0.017665      135.149117         0.272442
# 4                    0.018243      135.676869         0.235952
# ...                       ...             ...              ...
# 3995                 0.016506      121.377772         0.263975
# 3996                 0.016578      115.490005         0.198094
# 3997                 0.016918      126.094589         0.224443
# 3998                 0.016627      138.507475         0.300365
# 3999                 0.018623      135.981222         0.224016
#
# [4000 rows x 20 columns]

# %%
le = LabelEncoder()
df['label'] = le.fit_transform(df['rock_type'])
feature_cols = [
    'velocity', 'amplitude', 'duration', 'frequency_Hz',
    'velocity_x_amplitude', 'velocity_squared', 'duration_squared',
    'amplitude_duration', 'velocity_frequency', 'amplitude_frequency',
    'duration_frequency', 'velocity_duration', 'amplitude_squared',
    'frequency_squared', 'velocity_amplitude_ratio', 'duration_frequency_ratio',
    'velocity_duration_ratio', 'velocity_cubed', 'amplitude_cubed'
]

X = df[feature_cols].values
y = df['label'].values

from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

# %%
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y), y=y)
class_weights_dict = dict(enumerate(class_weights))

def create_model(input_dim, num_classes, dropout_rate=0.3):
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(input_dim,)),

        # First block
        tf.keras.layers.Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate),

        # Second block
        tf.keras.layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate),

        # Third block
        tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate * 0.5),

        # Fourth block
        tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate * 0.5),

        # Output layer
        tf.keras.layers.Dense(num_classes, activation='softmax')
    ])

    return model

model = create_model(X_scaled.shape[1], len(le.classes_))

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        patience=20,
        restore_best_weights=True,
        monitor='val_accuracy',
        min_delta=0.001
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        factor=0.3,
        patience=8,
        min_lr=1e-6,
        monitor='val_accuracy',
        verbose=1
    ),
    tf.keras.callbacks.ModelCheckpoint(
        "Silicate_model.keras",
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1
    )
]

model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_20 (Dense)                │ (None, 512)            │        10,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 5)              │           325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 186,885 (730.02 KB)
#  Trainable params: 184,965 (722.52 KB)
#  Non-trainable params: 1,920 (7.50 KB)

# %%
print("Training improved model...")
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=150,  # More epochs with early stopping
    batch_size=64,  # Larger batch size for stability
    callbacks=callbacks,
    class_weight=class_weights_dict,
    verbose=1
)
# Out:
# Training improved model...
# Epoch 1/150
# 44/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4218 - loss: 2.2263
# Epoch 1: val_accuracy improved from -inf to 0.47500, saving model to Silicate_model.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.4337 - loss: 2.1864 - val_accuracy: 0.4750 - val_loss: 1.9551 - learning_rate: 0.0010
# Epoch 2/150
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5265 - loss: 1.7921
# Epoch 2: val_accuracy did not improve from 0.47500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5273 - loss: 1.7900 - val_accuracy: 0.4437 - val_loss: 1.9338 - learning_rate: 0.0010
# Epoch 3/150
# 45/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5399 - loss: 1.7196
# Epoch 3: val_accuracy did not improve from 0.47500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5419 - loss: 1.7145 - val_accuracy: 0.4650 - val_loss: 1.8887 - learning_rate: 0.0010
# Epoch 4/150
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5599 - loss: 1.6691
# Epoch 4: val_accuracy improved from 0.47500 to 0.50625, saving model to Silicate_model.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5604 - loss: 1.6678 - val_accuracy: 0.5063 - val_loss: 1.7801 - learning_rate: 0.0010
# Epoch 5/150
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5574 - loss: 1.6325
# Epoch 5: val_accuracy improved from 0.50625 to 0.53000, saving model to Silicate_model.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.5579 - loss: 1.6316 - val_accuracy: 0.5300 - val_loss: 1.7128 - learning_rate: 0.0010
# Epoch 6/150
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5693 - loss: 1.5950
# Epoch 6: val_accuracy did not improve from 0.53000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5697 - loss: 1.5941 - val_accuracy: 0.5163 - val_loss: 1.6603 - learning_rate: 0.0010
# Epoch 7/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5503 - loss: 1.5846
# Epoch 7: val_accuracy improved from 0.53000 to 0.54375, saving model to Silicate_model.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5507 - loss: 1.5839 - val_accuracy: 0.5437 - val_loss: 1.5949 - learning_rate: 0.0010
# Epoch 8/150
# 48/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5606 - loss: 1.5513
# Epoch 8: val_accuracy improved from 0.54375 to 0.54750, saving model to Silicate_model.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5613 - loss: 1.5500 - val_accuracy: 0.5475 - val_loss: 1.5374 - learning_rate: 0.0010
# Epoch 9/150
# 48/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5791 - loss: 1.5261
# Epoch 9: val_accuracy improved from 0.54750 to 0.56250, saving model to Silicate_model.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5795 - loss: 1.5245 - val_accuracy: 0.5625 - val_loss: 1.5018 - learning_rate: 0.0010
# Epoch 10/150
# 46/50 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5584 - loss: 1.5064
# Epoch 10: val_accuracy did not improve from 0.56250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5601 - loss: 1.5037 - val_accuracy: 0.5462 - val_loss: 1.4815 - learning_rate: 0.0010
# Epoch 11/150
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5602 - loss: 1.4698
# Epoch 11: val_accuracy did not improve from 0.56250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5609 - loss: 1.4691 - val_accuracy: 0.5487 - val_loss: 1.4542 - learning_rate: 0.0010
# Epoch 12/150
# 45/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5691 - loss: 1.4389
# Epoch 12: val_accuracy did not improve from 0.56250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5707 - loss: 1.4366 - val_accuracy: 0.5587 - val_loss: 1.4318 - learning_rate: 0.0010
# Epoch 13/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5799 - loss: 1.4155
# Epoch 13: val_accuracy improved from 0.56250 to 0.56500, saving model to Silicate_model.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5801 - loss: 1.4152 - val_accuracy: 0.5650 - val_loss: 1.4212 - learning_rate: 0.0010
# Epoch 14/150
# 48/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5693 - loss: 1.3939
# Epoch 14: val_accuracy did not improve from 0.56500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5700 - loss: 1.3932 - val_accuracy: 0.5450 - val_loss: 1.4037 - learning_rate: 0.0010
# Epoch 15/150
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5611 - loss: 1.3853
# Epoch 15: val_accuracy did not improve from 0.56500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5617 - loss: 1.3844 - val_accuracy: 0.5412 - val_loss: 1.3828 - learning_rate: 0.0010
# Epoch 16/150
# 46/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5752 - loss: 1.3393
# Epoch 16: val_accuracy did not improve from 0.56500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5768 - loss: 1.3381 - val_accuracy: 0.5587 - val_loss: 1.3672 - learning_rate: 0.0010
# Epoch 17/150
# 44/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5637 - loss: 1.3401
# Epoch 17: val_accuracy did not improve from 0.56500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5658 - loss: 1.3370 - val_accuracy: 0.5525 - val_loss: 1.3479 - learning_rate: 0.0010
# Epoch 18/150
# 46/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5692 - loss: 1.3132
# Epoch 18: val_accuracy did not improve from 0.56500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5716 - loss: 1.3108 - val_accuracy: 0.5575 - val_loss: 1.3389 - learning_rate: 0.0010
# Epoch 19/150
# 48/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5636 - loss: 1.3198
# Epoch 19: val_accuracy did not improve from 0.56500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5649 - loss: 1.3180 - val_accuracy: 0.5537 - val_loss: 1.3262 - learning_rate: 0.0010
# Epoch 20/150
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5746 - loss: 1.2951
# Epoch 20: val_accuracy did not improve from 0.56500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5752 - loss: 1.2942 - val_accuracy: 0.5550 - val_loss: 1.3101 - learning_rate: 0.0010
# Epoch 21/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5725 - loss: 1.2752
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
#
# Epoch 21: val_accuracy did not improve from 0.56500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.5729 - loss: 1.2747 - val_accuracy: 0.5600 - val_loss: 1.2896 - learning_rate: 0.0010
# Epoch 22/150
# 47/50 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5834 - loss: 1.2453
# Epoch 22: val_accuracy did not improve from 0.56500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5852 - loss: 1.2434 - val_accuracy: 0.5425 - val_loss: 1.2806 - learning_rate: 3.0000e-04
# Epoch 23/150
# 45/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5808 - loss: 1.2262
# Epoch 23: val_accuracy did not improve from 0.56500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5827 - loss: 1.2244 - val_accuracy: 0.5525 - val_loss: 1.2825 - learning_rate: 3.0000e-04
# Epoch 24/150
# 48/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5845 - loss: 1.2214
# Epoch 24: val_accuracy did not improve from 0.56500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5852 - loss: 1.2205 - val_accuracy: 0.5550 - val_loss: 1.2788 - learning_rate: 3.0000e-04
# Epoch 25/150
# 45/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5746 - loss: 1.2223
# Epoch 25: val_accuracy did not improve from 0.56500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5768 - loss: 1.2197 - val_accuracy: 0.5575 - val_loss: 1.2734 - learning_rate: 3.0000e-04
# Epoch 26/150
# 47/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5971 - loss: 1.2146
# Epoch 26: val_accuracy did not improve from 0.56500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5979 - loss: 1.2129 - val_accuracy: 0.5537 - val_loss: 1.2723 - learning_rate: 3.0000e-04
# Epoch 27/150
# 46/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5751 - loss: 1.2193
# Epoch 27: val_accuracy did not improve from 0.56500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5774 - loss: 1.2170 - val_accuracy: 0.5475 - val_loss: 1.2686 - learning_rate: 3.0000e-04
# Epoch 28/150
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5727 - loss: 1.2057
# Epoch 28: val_accuracy did not improve from 0.56500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5737 - loss: 1.2048 - val_accuracy: 0.5450 - val_loss: 1.2635 - learning_rate: 3.0000e-04
# Epoch 29/150
# 47/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5852 - loss: 1.1828
# Epoch 29: val_accuracy improved from 0.56500 to 0.57250, saving model to Silicate_model.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5863 - loss: 1.1818 - val_accuracy: 0.5725 - val_loss: 1.2594 - learning_rate: 3.0000e-04
# Epoch 30/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5745 - loss: 1.2013
# Epoch 30: val_accuracy did not improve from 0.57250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5748 - loss: 1.2010 - val_accuracy: 0.5612 - val_loss: 1.2585 - learning_rate: 3.0000e-04
# Epoch 31/150
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5782 - loss: 1.1824
# Epoch 31: val_accuracy did not improve from 0.57250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5788 - loss: 1.1820 - val_accuracy: 0.5587 - val_loss: 1.2520 - learning_rate: 3.0000e-04
# Epoch 32/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5804 - loss: 1.1817
# Epoch 32: val_accuracy did not improve from 0.57250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5808 - loss: 1.1814 - val_accuracy: 0.5512 - val_loss: 1.2493 - learning_rate: 3.0000e-04
# Epoch 33/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5985 - loss: 1.1770
# Epoch 33: val_accuracy did not improve from 0.57250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5986 - loss: 1.1767 - val_accuracy: 0.5475 - val_loss: 1.2420 - learning_rate: 3.0000e-04
# Epoch 34/150
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5885 - loss: 1.1698
# Epoch 34: val_accuracy did not improve from 0.57250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5892 - loss: 1.1690 - val_accuracy: 0.5512 - val_loss: 1.2365 - learning_rate: 3.0000e-04
# Epoch 35/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5966 - loss: 1.1668
# Epoch 35: val_accuracy did not improve from 0.57250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5969 - loss: 1.1664 - val_accuracy: 0.5525 - val_loss: 1.2361 - learning_rate: 3.0000e-04
# Epoch 36/150
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5887 - loss: 1.1628
# Epoch 36: val_accuracy did not improve from 0.57250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5895 - loss: 1.1618 - val_accuracy: 0.5587 - val_loss: 1.2329 - learning_rate: 3.0000e-04
# Epoch 37/150
# 48/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5724 - loss: 1.1686
# Epoch 37: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
#
# Epoch 37: val_accuracy did not improve from 0.57250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5739 - loss: 1.1672 - val_accuracy: 0.5612 - val_loss: 1.2317 - learning_rate: 3.0000e-04
# Epoch 38/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5844 - loss: 1.1581
# Epoch 38: val_accuracy did not improve from 0.57250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5848 - loss: 1.1577 - val_accuracy: 0.5575 - val_loss: 1.2296 - learning_rate: 9.0000e-05
# Epoch 39/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5974 - loss: 1.1370
# Epoch 39: val_accuracy did not improve from 0.57250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5977 - loss: 1.1368 - val_accuracy: 0.5537 - val_loss: 1.2284 - learning_rate: 9.0000e-05
# Epoch 40/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5946 - loss: 1.1330
# Epoch 40: val_accuracy did not improve from 0.57250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5948 - loss: 1.1327 - val_accuracy: 0.5562 - val_loss: 1.2280 - learning_rate: 9.0000e-05
# Epoch 41/150
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5795 - loss: 1.1439
# Epoch 41: val_accuracy did not improve from 0.57250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5805 - loss: 1.1432 - val_accuracy: 0.5537 - val_loss: 1.2289 - learning_rate: 9.0000e-05
# Epoch 42/150
# 44/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5922 - loss: 1.1256
# Epoch 42: val_accuracy did not improve from 0.57250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5944 - loss: 1.1244 - val_accuracy: 0.5575 - val_loss: 1.2299 - learning_rate: 9.0000e-05
# Epoch 43/150
# 48/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5979 - loss: 1.1254
# Epoch 43: val_accuracy did not improve from 0.57250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5984 - loss: 1.1247 - val_accuracy: 0.5525 - val_loss: 1.2304 - learning_rate: 9.0000e-05
# Epoch 44/150
# 47/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5997 - loss: 1.1220
# Epoch 44: val_accuracy did not improve from 0.57250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.6003 - loss: 1.1211 - val_accuracy: 0.5462 - val_loss: 1.2298 - learning_rate: 9.0000e-05
# Epoch 45/150
# 47/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6091 - loss: 1.1190
# Epoch 45: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
#
# Epoch 45: val_accuracy did not improve from 0.57250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6094 - loss: 1.1183 - val_accuracy: 0.5537 - val_loss: 1.2269 - learning_rate: 9.0000e-05
# Epoch 46/150
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6033 - loss: 1.1233
# Epoch 46: val_accuracy did not improve from 0.57250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6039 - loss: 1.1228 - val_accuracy: 0.5550 - val_loss: 1.2272 - learning_rate: 2.7000e-05
# Epoch 47/150
# 46/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6016 - loss: 1.1214
# Epoch 47: val_accuracy did not improve from 0.57250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6025 - loss: 1.1209 - val_accuracy: 0.5525 - val_loss: 1.2275 - learning_rate: 2.7000e-05
# Epoch 48/150
# 46/50 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5925 - loss: 1.1307
# Epoch 48: val_accuracy did not improve from 0.57250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5944 - loss: 1.1289 - val_accuracy: 0.5537 - val_loss: 1.2270 - learning_rate: 2.7000e-05
# Epoch 49/150
# 48/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6020 - loss: 1.1172
# Epoch 49: val_accuracy did not improve from 0.57250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6028 - loss: 1.1166 - val_accuracy: 0.5525 - val_loss: 1.2274 - learning_rate: 2.7000e-05

# %%
model = tf.keras.models.load_model("Silicate_model.keras")

y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)

print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=le.classes_))

accuracy = np.mean(y_pred == y_test)
print(f"\nFinal Test Accuracy: {accuracy:.4f}")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    Amphibole       0.63      0.58      0.60       160
#     Feldspar       0.60      0.61      0.61       160
#         Mica       0.45      0.51      0.48       160
#      Olivine       0.71      0.76      0.73       160
#     Pyroxene       0.47      0.41      0.43       160
#
#     accuracy                           0.57       800
#    macro avg       0.57      0.57      0.57       800
# weighted avg       0.57      0.57      0.57       800
#
#
# Final Test Accuracy: 0.5725

# %%
plt.figure(figsize=(12, 8))
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d',
            xticklabels=le.classes_, yticklabels=le.classes_,
            cmap='Blues', cbar_kws={'label': 'Count'})
plt.title("Confusion Matrix - Improved Model")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
plt.title("Model Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True, alpha=0.3)

# %%
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
plt.title("Model Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
def get_feature_importance(model, X_test, feature_names):
    """Calculate feature importance using permutation importance"""
    baseline_accuracy = model.evaluate(X_test, y_test, verbose=0)[1]
    importance_scores = []
    for i, feature in enumerate(feature_names):
        X_test_permuted = X_test.copy()
        np.random.shuffle(X_test_permuted[:, i])
        permuted_accuracy = model.evaluate(X_test_permuted, y_test, verbose=0)[1]
        importance = baseline_accuracy - permuted_accuracy
        importance_scores.append(importance)
    return importance_scores
print("\nCalculating feature importance...")
importance_scores = get_feature_importance(model, X_test, feature_cols)
plt.figure(figsize=(12, 8))
feature_importance_df = pd.DataFrame({
    'feature': feature_cols,
    'importance': importance_scores
}).sort_values('importance', ascending=True)

plt.barh(feature_importance_df['feature'], feature_importance_df['importance'])
plt.title('Feature Importance (Permutation Importance)')
plt.xlabel('Importance Score')
plt.tight_layout()
plt.show()
# Out:
# Calculating feature importance...

# %%
joblib.dump(scaler, "Silicate_scaler.pkl")
joblib.dump(le, "Silicate_label_encoder.pkl")
print(f"\nModel saved as: Silicate_model.keras")
print(f"Scaler saved as: Silicate_scaler.pkl")
print(f"Label encoder saved as: Silicate_label_encoder.pkl")
print(f"Final accuracy: {accuracy:.4f}")
# Out:
# Model saved as: Silicate_model.keras
# Scaler saved as: Silicate_scaler.pkl
# Label encoder saved as: Silicate_label_encoder.pkl
# Final accuracy: 0.5725

# %%
import numpy as np
from tensorflow.keras.models import load_model
import joblib
model = load_model("Silicate_model.keras")
scaler = joblib.load("Silicate_scaler.pkl")
le = joblib.load("Silicate_label_encoder.pkl")
def engineer_features(velocity, amplitude, duration, frequency_hz):
    features = [velocity, amplitude, duration, frequency_hz]
    velocity_x_amplitude = velocity * amplitude
    velocity_squared = velocity ** 2
    duration_squared = duration ** 2
    amplitude_duration = amplitude * duration
    velocity_frequency = velocity * frequency_hz
    amplitude_frequency = amplitude * frequency_hz
    duration_frequency = duration * frequency_hz
    velocity_duration = velocity * duration
    amplitude_squared = amplitude ** 2
    frequency_squared = frequency_hz ** 2
    velocity_amplitude_ratio = velocity / amplitude
    duration_frequency_ratio = duration / frequency_hz
    velocity_duration_ratio = velocity / duration
    velocity_cubed = velocity ** 3
    amplitude_cubed = amplitude ** 3
    all_features = [
        velocity, amplitude, duration, frequency_hz,
        velocity_x_amplitude, velocity_squared, duration_squared,
        amplitude_duration, velocity_frequency, amplitude_frequency,
        duration_frequency, velocity_duration, amplitude_squared,
        frequency_squared, velocity_amplitude_ratio, duration_frequency_ratio,
        velocity_duration_ratio, velocity_cubed, amplitude_cubed
    ]
    return np.array(all_features).reshape(1, -1)
def predict_rock_type(velocity, amplitude, duration, frequency_hz, verbose=True):
    sample_features = engineer_features(velocity, amplitude, duration, frequency_hz)
    sample_scaled = scaler.transform(sample_features)
    pred_prob = model.predict(sample_scaled, verbose=0)
    pred_index = np.argmax(pred_prob)
    pred_label = le.inverse_transform([pred_index])[0]
    confidence = np.max(pred_prob)
    if verbose:
        print(f"\n🪨 Input Sample:")
        print(f"   Velocity: {velocity} km/s")
        print(f"   Amplitude: {amplitude}")
        print(f"   Duration: {duration} ms")
        print(f"   Frequency: {frequency_hz} Hz")
        print(f"\n📊 Prediction Results:")
        print(f"   Predicted Rock Type: {pred_label}")
        print(f"   Confidence: {confidence:.3f}")
        print(f"\n📈 All Probabilities:")
        for i, rock_type in enumerate(le.classes_):
            print(f"   {rock_type}: {pred_prob[0][i]:.3f}")
    return pred_label, confidence, pred_prob[0]
if __name__ == "__main__":
    vvelocity = 5.00
    amplitude = 0.60
    duration = 291
    frequency_hz = 43.8

    rock_type, confidence, probabilities = predict_rock_type(
        velocity, amplitude, duration, frequency_hz
    )
    print(f"\nFinal Result: {rock_type} (Confidence: {confidence:.3f})")
# Out:
# 🪨 Input Sample:
#    Velocity: 4.08 km/s
#    Amplitude: 0.6
#    Duration: 291 ms
#    Frequency: 43.8 Hz
#
# 📊 Prediction Results:
#    Predicted Rock Type: Mica
#    Confidence: 0.948
#
# 📈 All Probabilities:
#    Amphibole: 0.001
#    Feldspar: 0.000
#    Mica: 0.948
#    Olivine: 0.000
#    Pyroxene: 0.051
#
# Final Result: Mica (Confidence: 0.948)
