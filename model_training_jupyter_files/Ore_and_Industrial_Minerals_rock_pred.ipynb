# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import os

tf.random.set_seed(42)
np.random.seed(42)

igneous_rock_properties = {
    "Bauxite":     {"velocity": (4.1, 0.1), "amplitude": (0.50, 0.02), "duration": (230, 10), "frequency_Hz": (30, 5)},
    "Hematite":    {"velocity": (4.4, 0.1), "amplitude": (0.54, 0.02), "duration": (245, 10), "frequency_Hz": (34, 5)},
    "Magnetite":   {"velocity": (4.5, 0.1), "amplitude": (0.53, 0.02), "duration": (240, 10), "frequency_Hz": (36, 5)},
    "Barite":      {"velocity": (4.3, 0.1), "amplitude": (0.51, 0.02), "duration": (235, 10), "frequency_Hz": (32, 5)},
    "Gypsum":      {"velocity": (4.0, 0.1), "amplitude": (0.49, 0.02), "duration": (225, 10), "frequency_Hz": (28, 4)},

}

def generate_dataset(props, samples_per_class=800, seed=42):
    """Generate dataset with more samples for better training"""
    np.random.seed(seed)
    data = []

    for rock_type, features in props.items():
        for _ in range(samples_per_class):
            row = {
                "rock_type": rock_type,
                "velocity": np.random.normal(*features["velocity"]),
                "amplitude": np.random.normal(*features["amplitude"]),
                "duration": np.random.normal(*features["duration"]),
                "frequency_Hz": np.random.normal(*features["frequency_Hz"])
            }
            data.append(row)

    df = pd.DataFrame(data)
    df = df.sample(frac=1, random_state=seed).reset_index(drop=True)
    return df

df = generate_dataset(igneous_rock_properties)

df['velocity_x_amplitude'] = df['velocity'] * df['amplitude']
df['velocity_squared'] = df['velocity'] ** 2
df['duration_squared'] = df['duration'] ** 2
df['amplitude_duration'] = df['amplitude'] * df['duration']
df['velocity_frequency'] = df['velocity'] * df['frequency_Hz']
df['amplitude_frequency'] = df['amplitude'] * df['frequency_Hz']
df['duration_frequency'] = df['duration'] * df['frequency_Hz']
df['velocity_duration'] = df['velocity'] * df['duration']
df['amplitude_squared'] = df['amplitude'] ** 2
df['frequency_squared'] = df['frequency_Hz'] ** 2
df['velocity_amplitude_ratio'] = df['velocity'] / df['amplitude']
df['duration_frequency_ratio'] = df['duration'] / df['frequency_Hz']
df['velocity_duration_ratio'] = df['velocity'] / df['duration']
df['velocity_cubed'] = df['velocity'] ** 3
df['amplitude_cubed'] = df['amplitude'] ** 3

print(df)
# Out:
#      rock_type  velocity  amplitude    duration  frequency_Hz  \
# 0      Bauxite  4.064166   0.487049  237.441920     29.093879
# 1       Gypsum  4.017872   0.486524  234.959549     30.944910
# 2      Bauxite  4.067138   0.512064  224.558860     29.186035
# 3       Gypsum  4.031816   0.498273  215.513781     28.292417
# 4       Barite  4.438487   0.517933  226.668585     37.329819
# ...        ...       ...        ...         ...           ...
# 3995  Hematite  4.351229   0.561487  249.964001     44.375325
# 3996  Hematite  4.269841   0.502940  243.751131     34.078489
# 3997  Hematite  4.414552   0.527718  246.409827     41.943135
# 3998    Gypsum  4.073976   0.519704  236.176324     30.007408
# 3999    Barite  4.442326   0.507332  221.135106     29.380784
#
#       velocity_x_amplitude  velocity_squared  duration_squared  \
# 0                 1.979449         16.517445      56378.665238
# 1                 1.954790         16.143291      55205.989799
# 2                 2.082634         16.541613      50426.681595
# 3                 2.008945         16.255540      46446.189796
# 4                 2.298837         19.700168      51378.647320
# ...                    ...               ...               ...
# 3995              2.443157         18.933198      62482.001885
# 3996              2.147472         18.231544      59414.613935
# 3997              2.329637         19.488270      60717.802840
# 3998              2.117263         16.597280      55779.256215
# 3999              2.253735         19.734265      48900.735014
#
#       amplitude_duration  velocity_frequency  amplitude_frequency  \
# 0             115.645888          118.242354            14.170150
# 1             114.313390          124.332671            15.055432
# 2             114.988452          118.703638            14.945111
# 3             107.384689          114.069818            14.097346
# 4             117.399040          165.687919            19.334328
# ...                  ...                 ...                  ...
# 3995          140.351452          193.087222            24.916153
# 3996          122.592104          145.509736            17.139423
# 3997          130.034790          185.160154            22.134128
# 3998          122.741859          122.249459            15.594980
# 3999          112.188958          130.519036            14.905818
#
#       duration_frequency  velocity_duration  amplitude_squared  \
# 0            6908.106514         965.003373           0.237217
# 1            7270.802055         944.037280           0.236705
# 2            6553.982852         913.311907           0.262209
# 3            6097.405765         868.911896           0.248276
# 4            8461.497151        1006.065592           0.268254
# ...                  ...                ...                ...
# 3995        11092.233840        1087.650727           0.315267
# 3996         8306.670237        1040.778623           0.252948
# 3997        10335.200550        1087.789024           0.278486
# 3998         7087.039373         962.176661           0.270093
# 3999         6497.122811         982.354339           0.257386
#
#       frequency_squared  velocity_amplitude_ratio  duration_frequency_ratio  \
# 0            846.453803                  8.344468                  8.161233
# 1            957.587441                  8.258326                  7.592834
# 2            851.824666                  7.942640                  7.694051
# 3            800.460861                  8.091581                  7.617369
# 4           1393.515357                  8.569624                  6.072052
# ...                 ...                       ...                       ...
# 3995        1969.169486                  7.749480                  5.632950
# 3996        1161.343411                  8.489769                  7.152639
# 3997        1759.226543                  8.365369                  5.874855
# 3998         900.444547                  7.839026                  7.870601
# 3999         863.230477                  8.756248                  7.526522
#
#       velocity_duration_ratio  velocity_cubed  amplitude_cubed
# 0                    0.017116       67.129639         0.115536
# 1                    0.017100       64.861671         0.115163
# 2                    0.018112       67.277024         0.134268
# 3                    0.018708       65.539344         0.123709
# 4                    0.019581       87.438941         0.138938
# ...                       ...             ...              ...
# 3995                 0.017407       82.382688         0.177018
# 3996                 0.017517       77.845797         0.127218
# 3997                 0.017915       86.031985         0.146962
# 3998                 0.017250       67.616919         0.140368
# 3999                 0.020089       87.666047         0.130580
#
# [4000 rows x 20 columns]

# %%
le = LabelEncoder()
df['label'] = le.fit_transform(df['rock_type'])
feature_cols = [
    'velocity', 'amplitude', 'duration', 'frequency_Hz',
    'velocity_x_amplitude', 'velocity_squared', 'duration_squared',
    'amplitude_duration', 'velocity_frequency', 'amplitude_frequency',
    'duration_frequency', 'velocity_duration', 'amplitude_squared',
    'frequency_squared', 'velocity_amplitude_ratio', 'duration_frequency_ratio',
    'velocity_duration_ratio', 'velocity_cubed', 'amplitude_cubed'
]

X = df[feature_cols].values
y = df['label'].values

from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

# %%
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y), y=y)
class_weights_dict = dict(enumerate(class_weights))

def create_model(input_dim, num_classes, dropout_rate=0.3):
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(input_dim,)),

        # First block
        tf.keras.layers.Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate),

        # Second block
        tf.keras.layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate),

        # Third block
        tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate * 0.5),

        # Fourth block
        tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate * 0.5),

        # Output layer
        tf.keras.layers.Dense(num_classes, activation='softmax')
    ])

    return model

model = create_model(X_scaled.shape[1], len(le.classes_))

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        patience=20,
        restore_best_weights=True,
        monitor='val_accuracy',
        min_delta=0.001
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        factor=0.3,
        patience=8,
        min_lr=1e-6,
        monitor='val_accuracy',
        verbose=1
    ),
    tf.keras.callbacks.ModelCheckpoint(
        "Ore and Industrial Minerals_model.keras",
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1
    )
]

model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_15 (Dense)                │ (None, 512)            │        10,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 5)              │           325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 186,885 (730.02 KB)
#  Trainable params: 184,965 (722.52 KB)
#  Non-trainable params: 1,920 (7.50 KB)

# %%
print("Training improved model...")
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=150,  # More epochs with early stopping
    batch_size=64,  # Larger batch size for stability
    callbacks=callbacks,
    class_weight=class_weights_dict,
    verbose=1
)
# Out:
# Training improved model...
# Epoch 1/150
# 48/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4741 - loss: 1.9816
# Epoch 1: val_accuracy improved from -inf to 0.58625, saving model to Ore and Industrial Minerals_model.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.4778 - loss: 1.9681 - val_accuracy: 0.5863 - val_loss: 1.7958 - learning_rate: 0.0010
# Epoch 2/150
# 47/50 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5832 - loss: 1.5913
# Epoch 2: val_accuracy did not improve from 0.58625
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5847 - loss: 1.5871 - val_accuracy: 0.4588 - val_loss: 1.7403 - learning_rate: 0.0010
# Epoch 3/150
# 46/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6010 - loss: 1.5198
# Epoch 3: val_accuracy did not improve from 0.58625
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.6011 - loss: 1.5171 - val_accuracy: 0.4762 - val_loss: 1.6859 - learning_rate: 0.0010
# Epoch 4/150
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6052 - loss: 1.4875
# Epoch 4: val_accuracy did not improve from 0.58625
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6056 - loss: 1.4861 - val_accuracy: 0.4762 - val_loss: 1.6318 - learning_rate: 0.0010
# Epoch 5/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5962 - loss: 1.4700
# Epoch 5: val_accuracy did not improve from 0.58625
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.5964 - loss: 1.4692 - val_accuracy: 0.5437 - val_loss: 1.5146 - learning_rate: 0.0010
# Epoch 6/150
# 46/50 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6124 - loss: 1.4393
# Epoch 6: val_accuracy improved from 0.58625 to 0.59625, saving model to Ore and Industrial Minerals_model.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6132 - loss: 1.4357 - val_accuracy: 0.5962 - val_loss: 1.4453 - learning_rate: 0.0010
# Epoch 7/150
# 46/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6101 - loss: 1.4021
# Epoch 7: val_accuracy improved from 0.59625 to 0.61250, saving model to Ore and Industrial Minerals_model.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6116 - loss: 1.3991 - val_accuracy: 0.6125 - val_loss: 1.3716 - learning_rate: 0.0010
# Epoch 8/150
# 46/50 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6101 - loss: 1.3780
# Epoch 8: val_accuracy did not improve from 0.61250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.6114 - loss: 1.3746 - val_accuracy: 0.6087 - val_loss: 1.3330 - learning_rate: 0.0010
# Epoch 9/150
# 47/50 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6121 - loss: 1.3577
# Epoch 9: val_accuracy improved from 0.61250 to 0.63750, saving model to Ore and Industrial Minerals_model.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6130 - loss: 1.3551 - val_accuracy: 0.6375 - val_loss: 1.2772 - learning_rate: 0.0010
# Epoch 10/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6181 - loss: 1.3066
# Epoch 10: val_accuracy improved from 0.63750 to 0.63875, saving model to Ore and Industrial Minerals_model.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.6183 - loss: 1.3061 - val_accuracy: 0.6388 - val_loss: 1.2461 - learning_rate: 0.0010
# Epoch 11/150
# 47/50 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6322 - loss: 1.2957
# Epoch 11: val_accuracy improved from 0.63875 to 0.65125, saving model to Ore and Industrial Minerals_model.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6323 - loss: 1.2929 - val_accuracy: 0.6513 - val_loss: 1.2163 - learning_rate: 0.0010
# Epoch 12/150
# 45/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6154 - loss: 1.2794
# Epoch 12: val_accuracy improved from 0.65125 to 0.66750, saving model to Ore and Industrial Minerals_model.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.6168 - loss: 1.2752 - val_accuracy: 0.6675 - val_loss: 1.1899 - learning_rate: 0.0010
# Epoch 13/150
# 47/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6325 - loss: 1.2523
# Epoch 13: val_accuracy did not improve from 0.66750
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.6333 - loss: 1.2491 - val_accuracy: 0.6413 - val_loss: 1.1829 - learning_rate: 0.0010
# Epoch 14/150
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6322 - loss: 1.2114
# Epoch 14: val_accuracy did not improve from 0.66750
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.6323 - loss: 1.2105 - val_accuracy: 0.6488 - val_loss: 1.1558 - learning_rate: 0.0010
# Epoch 15/150
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6277 - loss: 1.1875
# Epoch 15: val_accuracy did not improve from 0.66750
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6281 - loss: 1.1865 - val_accuracy: 0.6488 - val_loss: 1.1392 - learning_rate: 0.0010
# Epoch 16/150
# 46/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6340 - loss: 1.1788
# Epoch 16: val_accuracy did not improve from 0.66750
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6347 - loss: 1.1759 - val_accuracy: 0.6587 - val_loss: 1.1144 - learning_rate: 0.0010
# Epoch 17/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6224 - loss: 1.1559
# Epoch 17: val_accuracy did not improve from 0.66750
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6225 - loss: 1.1555 - val_accuracy: 0.6637 - val_loss: 1.0955 - learning_rate: 0.0010
# Epoch 18/150
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6250 - loss: 1.1518
# Epoch 18: val_accuracy did not improve from 0.66750
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6251 - loss: 1.1506 - val_accuracy: 0.6612 - val_loss: 1.0822 - learning_rate: 0.0010
# Epoch 19/150
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6412 - loss: 1.1082
# Epoch 19: val_accuracy did not improve from 0.66750
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6414 - loss: 1.1074 - val_accuracy: 0.6600 - val_loss: 1.0661 - learning_rate: 0.0010
# Epoch 20/150
# 47/50 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6366 - loss: 1.1080
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
#
# Epoch 20: val_accuracy did not improve from 0.66750
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.6369 - loss: 1.1055 - val_accuracy: 0.6463 - val_loss: 1.0523 - learning_rate: 0.0010
# Epoch 21/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6292 - loss: 1.0784
# Epoch 21: val_accuracy did not improve from 0.66750
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6295 - loss: 1.0779 - val_accuracy: 0.6612 - val_loss: 1.0432 - learning_rate: 3.0000e-04
# Epoch 22/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6379 - loss: 1.0520
# Epoch 22: val_accuracy did not improve from 0.66750
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6382 - loss: 1.0516 - val_accuracy: 0.6488 - val_loss: 1.0384 - learning_rate: 3.0000e-04
# Epoch 23/150
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6432 - loss: 1.0551
# Epoch 23: val_accuracy did not improve from 0.66750
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.6433 - loss: 1.0545 - val_accuracy: 0.6525 - val_loss: 1.0367 - learning_rate: 3.0000e-04
# Epoch 24/150
# 48/50 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6480 - loss: 1.0466
# Epoch 24: val_accuracy did not improve from 0.66750
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.6482 - loss: 1.0454 - val_accuracy: 0.6662 - val_loss: 1.0270 - learning_rate: 3.0000e-04
# Epoch 25/150
# 47/50 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6409 - loss: 1.0450
# Epoch 25: val_accuracy did not improve from 0.66750
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.6416 - loss: 1.0429 - val_accuracy: 0.6600 - val_loss: 1.0257 - learning_rate: 3.0000e-04
# Epoch 26/150
# 48/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6523 - loss: 1.0290
# Epoch 26: val_accuracy did not improve from 0.66750
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6525 - loss: 1.0282 - val_accuracy: 0.6575 - val_loss: 1.0223 - learning_rate: 3.0000e-04
# Epoch 27/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6474 - loss: 1.0328
# Epoch 27: val_accuracy did not improve from 0.66750
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6475 - loss: 1.0326 - val_accuracy: 0.6525 - val_loss: 1.0176 - learning_rate: 3.0000e-04
# Epoch 28/150
# 44/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6391 - loss: 1.0295
# Epoch 28: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
#
# Epoch 28: val_accuracy did not improve from 0.66750
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6403 - loss: 1.0266 - val_accuracy: 0.6488 - val_loss: 1.0181 - learning_rate: 3.0000e-04
# Epoch 29/150
# 47/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6536 - loss: 1.0083
# Epoch 29: val_accuracy did not improve from 0.66750
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6540 - loss: 1.0067 - val_accuracy: 0.6513 - val_loss: 1.0123 - learning_rate: 9.0000e-05
# Epoch 30/150
# 46/50 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6480 - loss: 0.9988
# Epoch 30: val_accuracy did not improve from 0.66750
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.6483 - loss: 0.9975 - val_accuracy: 0.6538 - val_loss: 1.0093 - learning_rate: 9.0000e-05
# Epoch 31/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6555 - loss: 1.0119
# Epoch 31: val_accuracy did not improve from 0.66750
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6555 - loss: 1.0116 - val_accuracy: 0.6525 - val_loss: 1.0065 - learning_rate: 9.0000e-05
# Epoch 32/150
# 44/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6528 - loss: 0.9985
# Epoch 32: val_accuracy did not improve from 0.66750
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6536 - loss: 0.9967 - val_accuracy: 0.6525 - val_loss: 1.0053 - learning_rate: 9.0000e-05

# %%
model = tf.keras.models.load_model("Ore and Industrial Minerals_model.keras")

y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)

print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=le.classes_))

accuracy = np.mean(y_pred == y_test)
print(f"\nFinal Test Accuracy: {accuracy:.4f}")
# Out:
# WARNING:tensorflow:5 out of the last 29 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7ded8cf2a2a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Barite       0.63      0.71      0.67       160
#      Bauxite       0.62      0.61      0.61       160
#       Gypsum       0.74      0.71      0.72       160
#     Hematite       0.62      0.66      0.64       160
#    Magnetite       0.75      0.64      0.69       160
#
#     accuracy                           0.67       800
#    macro avg       0.67      0.67      0.67       800
# weighted avg       0.67      0.67      0.67       800
#
#
# Final Test Accuracy: 0.6675

# %%
plt.figure(figsize=(12, 8))
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d',
            xticklabels=le.classes_, yticklabels=le.classes_,
            cmap='Blues', cbar_kws={'label': 'Count'})
plt.title("Confusion Matrix - Improved Model")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
plt.title("Model Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True, alpha=0.3)

# %%
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
plt.title("Model Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
def get_feature_importance(model, X_test, feature_names):
    """Calculate feature importance using permutation importance"""
    baseline_accuracy = model.evaluate(X_test, y_test, verbose=0)[1]
    importance_scores = []
    for i, feature in enumerate(feature_names):
        X_test_permuted = X_test.copy()
        np.random.shuffle(X_test_permuted[:, i])
        permuted_accuracy = model.evaluate(X_test_permuted, y_test, verbose=0)[1]
        importance = baseline_accuracy - permuted_accuracy
        importance_scores.append(importance)
    return importance_scores
print("\nCalculating feature importance...")
importance_scores = get_feature_importance(model, X_test, feature_cols)
plt.figure(figsize=(12, 8))
feature_importance_df = pd.DataFrame({
    'feature': feature_cols,
    'importance': importance_scores
}).sort_values('importance', ascending=True)

plt.barh(feature_importance_df['feature'], feature_importance_df['importance'])
plt.title('Feature Importance (Permutation Importance)')
plt.xlabel('Importance Score')
plt.tight_layout()
plt.show()
# Out:
# Calculating feature importance...

# %%
joblib.dump(scaler, "Ore and Industrial Minerals_model_scaler.pkl")
joblib.dump(le, "Ore and Industrial Minerals_model_label_encoder.pkl")
print(f"\nModel saved as: Ore and Industrial Minerals_model_model.keras")
print(f"Scaler saved as: Ore and Industrial Minerals_model_scaler.pkl")
print(f"Label encoder saved as: Ore and Industrial Minerals_model_label_encoder.pkl")
print(f"Final accuracy: {accuracy:.4f}")
# Out:
# Model saved as: Ore and Industrial Minerals_model_model.keras
# Scaler saved as: Ore and Industrial Minerals_model_scaler.pkl
# Label encoder saved as: Ore and Industrial Minerals_model_label_encoder.pkl
# Final accuracy: 0.6675

# %%
import numpy as np
from tensorflow.keras.models import load_model
import joblib
model = load_model("Ore and Industrial Minerals_model.keras")
scaler = joblib.load("Ore and Industrial Minerals_model_scaler.pkl")
le = joblib.load("Ore and Industrial Minerals_model_label_encoder.pkl")
def engineer_features(velocity, amplitude, duration, frequency_hz):
    features = [velocity, amplitude, duration, frequency_hz]
    velocity_x_amplitude = velocity * amplitude
    velocity_squared = velocity ** 2
    duration_squared = duration ** 2
    amplitude_duration = amplitude * duration
    velocity_frequency = velocity * frequency_hz
    amplitude_frequency = amplitude * frequency_hz
    duration_frequency = duration * frequency_hz
    velocity_duration = velocity * duration
    amplitude_squared = amplitude ** 2
    frequency_squared = frequency_hz ** 2
    velocity_amplitude_ratio = velocity / amplitude
    duration_frequency_ratio = duration / frequency_hz
    velocity_duration_ratio = velocity / duration
    velocity_cubed = velocity ** 3
    amplitude_cubed = amplitude ** 3
    all_features = [
        velocity, amplitude, duration, frequency_hz,
        velocity_x_amplitude, velocity_squared, duration_squared,
        amplitude_duration, velocity_frequency, amplitude_frequency,
        duration_frequency, velocity_duration, amplitude_squared,
        frequency_squared, velocity_amplitude_ratio, duration_frequency_ratio,
        velocity_duration_ratio, velocity_cubed, amplitude_cubed
    ]
    return np.array(all_features).reshape(1, -1)
def predict_rock_type(velocity, amplitude, duration, frequency_hz, verbose=True):
    sample_features = engineer_features(velocity, amplitude, duration, frequency_hz)
    sample_scaled = scaler.transform(sample_features)
    pred_prob = model.predict(sample_scaled, verbose=0)
    pred_index = np.argmax(pred_prob)
    pred_label = le.inverse_transform([pred_index])[0]
    confidence = np.max(pred_prob)
    if verbose:
        print(f"\n🪨 Input Sample:")
        print(f"   Velocity: {velocity} km/s")
        print(f"   Amplitude: {amplitude}")
        print(f"   Duration: {duration} ms")
        print(f"   Frequency: {frequency_hz} Hz")
        print(f"\n📊 Prediction Results:")
        print(f"   Predicted Rock Type: {pred_label}")
        print(f"   Confidence: {confidence:.3f}")
        print(f"\n📈 All Probabilities:")
        for i, rock_type in enumerate(le.classes_):
            print(f"   {rock_type}: {pred_prob[0][i]:.3f}")
    return pred_label, confidence, pred_prob[0]
if __name__ == "__main__":
    velocity = 4.08
    amplitude = 0.50
    duration = 229
    frequency_hz = 29.8
    rock_type, confidence, probabilities = predict_rock_type(
        velocity, amplitude, duration, frequency_hz
    )
    print(f"\nFinal Result: {rock_type} (Confidence: {confidence:.3f})")
# Out:
# 🪨 Input Sample:
#    Velocity: 4.08 km/s
#    Amplitude: 0.5
#    Duration: 229 ms
#    Frequency: 29.8 Hz
#
# 📊 Prediction Results:
#    Predicted Rock Type: Bauxite
#    Confidence: 0.584
#
# 📈 All Probabilities:
#    Barite: 0.073
#    Bauxite: 0.584
#    Gypsum: 0.333
#    Hematite: 0.004
#    Magnetite: 0.006
#
# Final Result: Bauxite (Confidence: 0.584)
